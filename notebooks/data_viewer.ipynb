# %%
from matplotlib import pyplot as plt
import fastf1
import fastf1.plotting

fastf1.plotting.setup_mpl(misc_mpl_mods=False, color_scheme='fastf1')

session = fastf1.get_session(2025, 'Canada', 'R')

session.load()
fast_verstappen = session.laps.pick_drivers('VER').pick_fastest()
ver_car_data = fast_verstappen.get_car_data()
t = ver_car_data['Time']
vCar = ver_car_data['Speed']

# The rest is just plotting
fig, ax = plt.subplots()
ax.plot(t, vCar, label='Fast')
ax.set_xlabel('Time')
ax.set_ylabel('Speed [Km/h]')
ax.set_title('Verstappen is')
ax.legend()
plt.show()
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '12', '81', '16', '44', '14', '27', '31', '55', '87', '22', '43', '5', '10', '6', '18', '4', '30', '23']

# %%
import fastf1

session = fastf1.get_session(2025, 'Canada', 'Q')
session.name
session.date
session.event
# Out:
# RoundNumber                                                   10
# Country                                                   Canada
# Location                                                Montréal
# OfficialEventName    FORMULA 1 PIRELLI GRAND PRIX DU CANADA 2025
# EventDate                                    2025-06-15 00:00:00
# EventName                                    Canadian Grand Prix
# EventFormat                                         conventional
# Session1                                              Practice 1
# Session1Date                           2025-06-13 13:30:00-04:00
# Session1DateUtc                              2025-06-13 17:30:00
# Session2                                              Practice 2
# Session2Date                           2025-06-13 17:00:00-04:00
# Session2DateUtc                              2025-06-13 21:00:00
# Session3                                              Practice 3
# Session3Date                           2025-06-14 12:30:00-04:00
# Session3DateUtc                              2025-06-14 16:30:00
# Session4                                              Qualifying
# Session4Date                           2025-06-14 16:00:00-04:00
# Session4DateUtc                              2025-06-14 20:00:00
# Session5                                                    Race
# Session5Date                           2025-06-15 14:00:00-04:00
# Session5DateUtc                              2025-06-15 18:00:00
# F1ApiSupport                                                True
# Name: 10, dtype: object

# %%
import fastf1

session = fastf1.get_session(2025, 'Canada', 'R')
session.load()
session.results
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '12', '81', '16', '44', '14', '27', '31', '55', '87', '22', '43', '5', '10', '6', '18', '4', '30', '23']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 27           27  N HULKENBERG          HUL      hulkenberg      Kick Sauber
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 55           55       C SAINZ          SAI           sainz         Williams
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 22           22     Y TSUNODA          TSU         tsunoda  Red Bull Racing
# 43           43   F COLAPINTO          COL       colapinto           Alpine
# 5             5   G BORTOLETO          BOR       bortoleto      Kick Sauber
# 10           10       P GASLY          GAS           gasly           Alpine
# 6             6      I HADJAR          HAD          hadjar     Racing Bulls
# 18           18      L STROLL          STR          stroll     Aston Martin
# 4             4      L NORRIS          NOR          norris          McLaren
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 23           23       A ALBON          ALB           albon         Williams
#
#    TeamColor        TeamId  FirstName    LastName           FullName  ...  \
# 63    00D7B6      mercedes     George     Russell     George Russell  ...
# 1     4781D7      red_bull        Max  Verstappen     Max Verstappen  ...
# 12    00D7B6      mercedes       Kimi   Antonelli     Kimi Antonelli  ...
# 81    F47600       mclaren      Oscar     Piastri      Oscar Piastri  ...
# 16    ED1131       ferrari    Charles     Leclerc    Charles Leclerc  ...
# 44    ED1131       ferrari      Lewis    Hamilton     Lewis Hamilton  ...
# 14    229971  aston_martin   Fernando      Alonso    Fernando Alonso  ...
# 27    01C00E        sauber       Nico  Hulkenberg    Nico Hulkenberg  ...
# 31    9C9FA2          haas    Esteban        Ocon       Esteban Ocon  ...
# 55    1868DB      williams     Carlos       Sainz       Carlos Sainz  ...
# 87    9C9FA2          haas     Oliver     Bearman     Oliver Bearman  ...
# 22    4781D7      red_bull       Yuki     Tsunoda       Yuki Tsunoda  ...
# 43    00A1E8        alpine     Franco   Colapinto   Franco Colapinto  ...
# 5     01C00E        sauber    Gabriel   Bortoleto  Gabriel Bortoleto  ...
# 10    00A1E8        alpine     Pierre       Gasly       Pierre Gasly  ...
# 6     6C98FF            rb      Isack      Hadjar       Isack Hadjar  ...
# 18    229971  aston_martin      Lance      Stroll       Lance Stroll  ...
# 4     F47600       mclaren      Lando      Norris       Lando Norris  ...
# 30    6C98FF            rb       Liam      Lawson        Liam Lawson  ...
# 23    1868DB      williams  Alexander       Albon    Alexander Albon  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 63                  1.0                   1          1.0 NaT NaT NaT
# 1                   2.0                   2          2.0 NaT NaT NaT
# 12                  3.0                   3          4.0 NaT NaT NaT
# 81                  4.0                   4          3.0 NaT NaT NaT
# 16                  5.0                   5          8.0 NaT NaT NaT
# 44                  6.0                   6          5.0 NaT NaT NaT
# 14                  7.0                   7          6.0 NaT NaT NaT
# 27                  8.0                   8         11.0 NaT NaT NaT
# 31                  9.0                   9         14.0 NaT NaT NaT
# 55                 10.0                  10         16.0 NaT NaT NaT
# 87                 11.0                  11         13.0 NaT NaT NaT
# 22                 12.0                  12         18.0 NaT NaT NaT
# 43                 13.0                  13         10.0 NaT NaT NaT
# 5                  14.0                  14         15.0 NaT NaT NaT
# 10                 15.0                  15         20.0 NaT NaT NaT
# 6                  16.0                  16         12.0 NaT NaT NaT
# 18                 17.0                  17         17.0 NaT NaT NaT
# 4                  18.0                  18          7.0 NaT NaT NaT
# 30                 19.0                   R         19.0 NaT NaT NaT
# 23                 20.0                   R          9.0 NaT NaT NaT
#
#                      Time    Status Points
# 63 0 days 01:31:52.688000  Finished   25.0
# 1  0 days 00:00:00.228000  Finished   18.0
# 12 0 days 00:00:01.014000  Finished   15.0
# 81 0 days 00:00:02.109000  Finished   12.0
# 16 0 days 00:00:03.442000  Finished   10.0
# 44 0 days 00:00:10.713000  Finished    8.0
# 14 0 days 00:00:10.972000  Finished    6.0
# 27 0 days 00:00:15.364000  Finished    4.0
# 31 0 days 00:00:01.473000    Lapped    2.0
# 55 0 days 00:00:01.886000    Lapped    1.0
# 87 0 days 00:00:03.717000    Lapped    0.0
# 22 0 days 00:00:05.456000    Lapped    0.0
# 43 0 days 00:00:07.018000    Lapped    0.0
# 5  0 days 00:00:07.879000    Lapped    0.0
# 10 0 days 00:00:07.950000    Lapped    0.0
# 6  0 days 00:00:08.737000    Lapped    0.0
# 18 0 days 00:00:09.063000    Lapped    0.0
# 4                     NaT   Retired    0.0
# 30                    NaT   Retired    0.0
# 23                    NaT   Retired    0.0
#
# [20 rows x 21 columns]

# %%
import fastf1

session = fastf1.get_session(2025, 'Canada', 'R')
session.load()
session.laps
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '12', '81', '16', '44', '14', '27', '31', '55', '87', '22', '43', '5', '10', '6', '18', '4', '30', '23']
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 00:59:22.413000    VER            1 0 days 00:01:22.549000
# 1    0 days 01:00:38.831000    VER            1 0 days 00:01:16.418000
# 2    0 days 01:01:54.925000    VER            1 0 days 00:01:16.094000
# 3    0 days 01:03:10.850000    VER            1 0 days 00:01:15.925000
# 4    0 days 01:04:26.751000    VER            1 0 days 00:01:15.901000
# ...                     ...    ...          ...                    ...
# 1344 0 days 02:22:11.284000    BEA           87 0 days 00:01:15.476000
# 1345 0 days 02:24:10.147000    BEA           87 0 days 00:01:58.863000
# 1346 0 days 02:26:06.979000    BEA           87 0 days 00:01:56.832000
# 1347 0 days 02:27:54.044000    BEA           87 0 days 00:01:47.065000
# 1348 0 days 02:29:56.269000    BEA           87 0 days 00:02:02.225000
#
#       LapNumber  Stint             PitOutTime              PitInTime  \
# 0           1.0    1.0                    NaT                    NaT
# 1           2.0    1.0                    NaT                    NaT
# 2           3.0    1.0                    NaT                    NaT
# 3           4.0    1.0                    NaT                    NaT
# 4           5.0    1.0                    NaT                    NaT
# ...         ...    ...                    ...                    ...
# 1344       65.0    2.0                    NaT                    NaT
# 1345       66.0    2.0                    NaT 0 days 02:23:43.804000
# 1346       67.0    3.0 0 days 02:24:11.741000 0 days 02:25:50.301000
# 1347       68.0    4.0 0 days 02:26:08.505000 0 days 02:27:37.362000
# 1348       69.0    5.0 0 days 02:27:55.534000                    NaT
#
#                 Sector1Time            Sector2Time  ... FreshTyre  \
# 0                       NaT 0 days 00:00:24.494000  ...     False
# 1    0 days 00:00:21.742000 0 days 00:00:24.204000  ...     False
# 2    0 days 00:00:21.507000 0 days 00:00:24.075000  ...     False
# 3    0 days 00:00:21.552000 0 days 00:00:24.012000  ...     False
# 4    0 days 00:00:21.429000 0 days 00:00:24.059000  ...     False
# ...                     ...                    ...  ...       ...
# 1344 0 days 00:00:21.034000 0 days 00:00:23.813000  ...      True
# 1345 0 days 00:00:26.852000 0 days 00:00:32.728000  ...      True
# 1346 0 days 00:00:31.324000 0 days 00:00:34.649000  ...      True
# 1347 0 days 00:00:29.283000 0 days 00:00:25.581000  ...     False
# 1348 0 days 00:00:31.481000 0 days 00:00:36.457000  ...     False
#
#                  Team           LapStartTime            LapStartDate  \
# 0     Red Bull Racing 0 days 00:57:59.581000 2025-06-15 18:03:04.636
# 1     Red Bull Racing 0 days 00:59:22.413000 2025-06-15 18:04:27.468
# 2     Red Bull Racing 0 days 01:00:38.831000 2025-06-15 18:05:43.886
# 3     Red Bull Racing 0 days 01:01:54.925000 2025-06-15 18:06:59.980
# 4     Red Bull Racing 0 days 01:03:10.850000 2025-06-15 18:08:15.905
# ...               ...                    ...                     ...
# 1344     Haas F1 Team 0 days 02:20:55.808000 2025-06-15 19:26:00.863
# 1345     Haas F1 Team 0 days 02:22:11.284000 2025-06-15 19:27:16.339
# 1346     Haas F1 Team 0 days 02:24:10.147000 2025-06-15 19:29:15.202
# 1347     Haas F1 Team 0 days 02:26:06.979000 2025-06-15 19:31:12.034
# 1348     Haas F1 Team 0 days 02:27:54.044000 2025-06-15 19:32:59.099
#
#       TrackStatus  Position  Deleted  DeletedReason FastF1Generated IsAccurate
# 0               1       2.0    False                          False      False
# 1               1       2.0    False                          False       True
# 2               1       2.0    False                          False       True
# 3               1       2.0    False                          False       True
# 4               1       2.0    False                          False       True
# ...           ...       ...      ...            ...             ...        ...
# 1344           12      12.0    False                          False       True
# 1345           24      12.0    False                          False      False
# 1346            4      11.0    False                          False      False
# 1347            4      11.0    False                          False      False
# 1348            4      11.0    False                          False      False
#
# [1349 rows x 31 columns]

# %%
import fastf1
from fastf1.ergast import Ergast

SEASON = 2025
ROUND = 11

def get_drivers_standings():
    ergast = Ergast()
    standings = ergast.get_driver_standings(season=SEASON, round=ROUND)
    return standings.content[0]

def calculate_max_points_for_remaining_season():
    POINTS_FOR_SPRINT = 8 + 25 + 1  # Winning the sprint, race and fastest lap
    POINTS_FOR_CONVENTIONAL = 25 + 1  # Winning the race and fastest lap

    events = fastf1.events.get_event_schedule(SEASON, backend='ergast')
    events = events[events['RoundNumber'] > ROUND]
    # Count how many sprints and conventional races are left
    sprint_events = len(events.loc[events["EventFormat"] == "sprint_shootout"])
    conventional_events = len(events.loc[events["EventFormat"] == "conventional"])

    # Calculate points for each
    sprint_points = sprint_events * POINTS_FOR_SPRINT
    conventional_points = conventional_events * POINTS_FOR_CONVENTIONAL

    return sprint_points + conventional_points

def calculate_who_can_win(driver_standings, max_points):
    LEADER_POINTS = int(driver_standings.loc[0]['points'])

    for i, _ in enumerate(driver_standings.iterrows()):
        driver = driver_standings.loc[i]
        driver_max_points = int(driver["points"]) + max_points
        can_win = 'No' if driver_max_points < LEADER_POINTS else 'Yes'

        print(f"{driver['position']}: {driver['givenName'] + ' ' + driver['familyName']}, "
              f"Current points: {driver['points']}, "
              f"Theoretical max points: {driver_max_points}, "
              f"Can win: {can_win}")

# Get the current drivers standings
driver_standings = get_drivers_standings()

# Get the maximum amount of points
points = calculate_max_points_for_remaining_season()

# Print which drivers can still win
calculate_who_can_win(driver_standings, points)
# Out:
# 1: Oscar Piastri, Current points: 216.0, Theoretical max points: 450, Can win: Yes
# 2: Lando Norris, Current points: 201.0, Theoretical max points: 435, Can win: Yes
# 3: Max Verstappen, Current points: 155.0, Theoretical max points: 389, Can win: Yes
# 4: George Russell, Current points: 146.0, Theoretical max points: 380, Can win: Yes
# 5: Charles Leclerc, Current points: 119.0, Theoretical max points: 353, Can win: Yes
# 6: Lewis Hamilton, Current points: 91.0, Theoretical max points: 325, Can win: Yes
# 7: Andrea Kimi Antonelli, Current points: 63.0, Theoretical max points: 297, Can win: Yes
# 8: Alexander Albon, Current points: 42.0, Theoretical max points: 276, Can win: Yes
# 9: Esteban Ocon, Current points: 23.0, Theoretical max points: 257, Can win: Yes
# 10: Nico Hülkenberg, Current points: 22.0, Theoretical max points: 256, Can win: Yes
# 11: Isack Hadjar, Current points: 21.0, Theoretical max points: 255, Can win: Yes
# 12: Lance Stroll, Current points: 14.0, Theoretical max points: 248, Can win: Yes
# 13: Fernando Alonso, Current points: 14.0, Theoretical max points: 248, Can win: Yes
# 14: Carlos Sainz, Current points: 13.0, Theoretical max points: 247, Can win: Yes
# 15: Liam Lawson, Current points: 12.0, Theoretical max points: 246, Can win: Yes
# 16: Pierre Gasly, Current points: 11.0, Theoretical max points: 245, Can win: Yes
# 17: Yuki Tsunoda, Current points: 10.0, Theoretical max points: 244, Can win: Yes
# 18: Oliver Bearman, Current points: 6.0, Theoretical max points: 240, Can win: Yes
# 19: Gabriel Bortoleto, Current points: 4.0, Theoretical max points: 238, Can win: Yes
# 20: Franco Colapinto, Current points: 0.0, Theoretical max points: 234, Can win: Yes
# 21: Jack Doohan, Current points: 0.0, Theoretical max points: 234, Can win: Yes

# %%
import fastf1

tes
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '12', '81', '16', '44', '14', '27', '31', '55', '87', '22', '43', '5', '10', '6', '18', '4', '30', '23']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 27           27  N HULKENBERG          HUL      hulkenberg      Kick Sauber
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 55           55       C SAINZ          SAI           sainz         Williams
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 22           22     Y TSUNODA          TSU         tsunoda  Red Bull Racing
# 43           43   F COLAPINTO          COL       colapinto           Alpine
# 5             5   G BORTOLETO          BOR       bortoleto      Kick Sauber
# 10           10       P GASLY          GAS           gasly           Alpine
# 6             6      I HADJAR          HAD          hadjar     Racing Bulls
# 18           18      L STROLL          STR          stroll     Aston Martin
# 4             4      L NORRIS          NOR          norris          McLaren
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 23           23       A ALBON          ALB           albon         Williams
#
#    TeamColor        TeamId  FirstName    LastName           FullName  ...  \
# 63    00D7B6      mercedes     George     Russell     George Russell  ...
# 1     4781D7      red_bull        Max  Verstappen     Max Verstappen  ...
# 12    00D7B6      mercedes       Kimi   Antonelli     Kimi Antonelli  ...
# 81    F47600       mclaren      Oscar     Piastri      Oscar Piastri  ...
# 16    ED1131       ferrari    Charles     Leclerc    Charles Leclerc  ...
# 44    ED1131       ferrari      Lewis    Hamilton     Lewis Hamilton  ...
# 14    229971  aston_martin   Fernando      Alonso    Fernando Alonso  ...
# 27    01C00E        sauber       Nico  Hulkenberg    Nico Hulkenberg  ...
# 31    9C9FA2          haas    Esteban        Ocon       Esteban Ocon  ...
# 55    1868DB      williams     Carlos       Sainz       Carlos Sainz  ...
# 87    9C9FA2          haas     Oliver     Bearman     Oliver Bearman  ...
# 22    4781D7      red_bull       Yuki     Tsunoda       Yuki Tsunoda  ...
# 43    00A1E8        alpine     Franco   Colapinto   Franco Colapinto  ...
# 5     01C00E        sauber    Gabriel   Bortoleto  Gabriel Bortoleto  ...
# 10    00A1E8        alpine     Pierre       Gasly       Pierre Gasly  ...
# 6     6C98FF            rb      Isack      Hadjar       Isack Hadjar  ...
# 18    229971  aston_martin      Lance      Stroll       Lance Stroll  ...
# 4     F47600       mclaren      Lando      Norris       Lando Norris  ...
# 30    6C98FF            rb       Liam      Lawson        Liam Lawson  ...
# 23    1868DB      williams  Alexander       Albon    Alexander Albon  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 63                  1.0                   1          1.0 NaT NaT NaT
# 1                   2.0                   2          2.0 NaT NaT NaT
# 12                  3.0                   3          4.0 NaT NaT NaT
# 81                  4.0                   4          3.0 NaT NaT NaT
# 16                  5.0                   5          8.0 NaT NaT NaT
# 44                  6.0                   6          5.0 NaT NaT NaT
# 14                  7.0                   7          6.0 NaT NaT NaT
# 27                  8.0                   8         11.0 NaT NaT NaT
# 31                  9.0                   9         14.0 NaT NaT NaT
# 55                 10.0                  10         16.0 NaT NaT NaT
# 87                 11.0                  11         13.0 NaT NaT NaT
# 22                 12.0                  12         18.0 NaT NaT NaT
# 43                 13.0                  13         10.0 NaT NaT NaT
# 5                  14.0                  14         15.0 NaT NaT NaT
# 10                 15.0                  15         20.0 NaT NaT NaT
# 6                  16.0                  16         12.0 NaT NaT NaT
# 18                 17.0                  17         17.0 NaT NaT NaT
# 4                  18.0                  18          7.0 NaT NaT NaT
# 30                 19.0                   R         19.0 NaT NaT NaT
# 23                 20.0                   R          9.0 NaT NaT NaT
#
#                      Time    Status Points
# 63 0 days 01:31:52.688000  Finished   25.0
# 1  0 days 00:00:00.228000  Finished   18.0
# 12 0 days 00:00:01.014000  Finished   15.0
# 81 0 days 00:00:02.109000  Finished   12.0
# 16 0 days 00:00:03.442000  Finished   10.0
# 44 0 days 00:00:10.713000  Finished    8.0
# 14 0 days 00:00:10.972000  Finished    6.0
# 27 0 days 00:00:15.364000  Finished    4.0
# 31 0 days 00:00:01.473000    Lapped    2.0
# 55 0 days 00:00:01.886000    Lapped    1.0
# 87 0 days 00:00:03.717000    Lapped    0.0
# 22 0 days 00:00:05.456000    Lapped    0.0
# 43 0 days 00:00:07.018000    Lapped    0.0
# 5  0 days 00:00:07.879000    Lapped    0.0
# 10 0 days 00:00:07.950000    Lapped    0.0
# 6  0 days 00:00:08.737000    Lapped    0.0
# 18 0 days 00:00:09.063000    Lapped    0.0
# 4                     NaT   Retired    0.0
# 30                    NaT   Retired    0.0
# 23                    NaT   Retired    0.0
#
# [20 rows x 21 columns]
